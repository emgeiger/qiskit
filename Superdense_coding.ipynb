# %%
from qiskit import QuantumCircuit, ClassicalRegister, transpile
from qiskit import *
# from qiskit import Aer, *
from qiskit_aer import Aer, AerSimulator
from qiskit.visualization import plot_histogram
# %matplotlib inline

# %%
circuit = QuantumCircuit(2)

# Prepare the Bell state and distribute the qubits
circuit.h(0)
circuit.cx(0, 1)

circuit.barrier()

match message :='10':
    case '00':
        circuit.id(0)
    case '01':
        circuit.z(0)
    case '10':
        circuit.x(0)
    case '11':
        circuit.z(0)
        circuit.x(0)
    
circuit.barrier()
circuit.cx(0, 1)
circuit.h(0)
circuit.measure_all()
circuit.draw(output='mpl')

# %%
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
result = simulator.run(compiled_circuit).result()

plot_histogram(result.get_counts(compiled_circuit))

# %% [markdown]
# ## Section 2

# %%
circuit = QuantumCircuit(2)

# Prepare the Bell state and distribute the qubits
circuit.h(0)
circuit.cx(0, 1)

circuit.barrier()

match message :='11':
    case '00':
        circuit.id(0)
    case '01':
        circuit.z(0)
    case '10':
        circuit.x(0)
    case '11':
        circuit.z(0)
        circuit.x(0)
    
circuit.barrier()
circuit.cx(0, 1)
circuit.h(0)
circuit.measure_all()
circuit.draw(output='mpl')

# %%
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
result = simulator.run(compiled_circuit).result()

plot_histogram(result.get_counts(compiled_circuit))
